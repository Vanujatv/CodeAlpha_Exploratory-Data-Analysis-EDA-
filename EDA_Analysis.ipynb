# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ankit\Downloads\yearly_sales.csv")

# %%
df.head()
# Out:
#    cust_id  sales_total  num_of_orders gender
# 0   100001       800.64              3      F
# 1   100002       217.53              3      F
# 2   100003        74.58              2      M
# 3   100004       498.60              3      M
# 4   100005       723.11              4      F

# %%
df.shape
# Out:
# (10000, 4)

# %%
df.info
# Out:
# <bound method DataFrame.info of       cust_id  sales_total  num_of_orders gender
# 0      100001   800.640000              3      F
# 1      100002   217.530000              3      F
# 2      100003    74.580000              2      M
# 3      100004   498.600000              3      M
# 4      100005   723.110000              4      F
# ...       ...          ...            ...    ...
# 9995   109996   190.270000              1      F
# 9996   109997    45.280000              2      F
# 9997   109998   152.070000              2      M
# 9998   109999    87.670000              1      M
# 9999   110000    97.163447              2      M
#
# [10000 rows x 4 columns]>

# %%
df.describe()
# Out:
#             cust_id   sales_total  num_of_orders
# count   10000.00000  10000.000000   10000.000000
# mean   105000.50000    249.455676       2.428000
# std      2886.89568    319.050782       1.441119
# min    100001.00000     30.020000       1.000000
# 25%    102500.75000     80.292500       2.000000
# 50%    105000.50000    151.650000       2.000000
# 75%    107500.25000    295.502500       3.000000
# max    110000.00000   7606.090000      22.000000

# %%
df.isnull().sum()
# Out:
# cust_id          0
# sales_total      0
# num_of_orders    0
# gender           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# cust_id            int64
# sales_total      float64
# num_of_orders      int64
# gender            object
# dtype: object

# %%
df.nunique()
# Out:
# cust_id          10000
# sales_total       9027
# num_of_orders       20
# gender               2
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='gender', data=df)
plt.title("Gender Distribution")
plt.show()

# %%
plt.hist(df['sales_total'], bins=20)
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
sns.countplot(x='num_of_orders', data=df)
plt.title("Number of Orders")
plt.show()

# %%
sns.boxplot(x=df['sales_total'])
plt.title("Sales Outliers")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
